# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import train_test_val_split

# %%
# inlets
inlets = pd.read_csv("datasets/all_inlets.csv")
inlets = inlets.drop(["Time"], axis=1)
inlets = inlets.add_prefix("inlet_")

# outlets
outlets = pd.read_csv("datasets/all_outlets.csv")
outlets = outlets.drop(["Time"], axis=1)
outlets = outlets.add_prefix("outlet_")

# %%
df = pd.concat([inlets, outlets], axis=1)

# %%
df.to_csv("datasets/df.csv", index=False)

# %%
df['inlet_Case_id'].value_counts()
# Out:
# 5    783
# 4    371
# 3    211
# 2    204
# 1    183
# Name: inlet_Case_id, dtype: int64

# %%
case_1 = df[df['inlet_Case_id'] == 1]
case_2 = df[df['inlet_Case_id'] == 2]
case_3 = df[df['inlet_Case_id'] == 3]
case_4 = df[df['inlet_Case_id'] == 4]
case_5 = df[df['inlet_Case_id'] == 5]

# %%
# Drop Case id columns
case_1 = case_1.drop(['inlet_Case_id', 'outlet_Case_id'], axis=1)
case_2 = case_2.drop(['inlet_Case_id', 'outlet_Case_id'], axis=1)
case_3 = case_3.drop(['inlet_Case_id', 'outlet_Case_id'], axis=1)
case_4 = case_4.drop(['inlet_Case_id', 'outlet_Case_id'], axis=1)
case_5 = case_5.drop(['inlet_Case_id', 'outlet_Case_id'], axis=1)

# %%
# Export to csv format
case_1.to_csv('datasets/case_1.csv', index=False)
case_2.to_csv('datasets/case_2.csv', index=False)
case_3.to_csv('datasets/case_3.csv', index=False)
case_4.to_csv('datasets/case_4.csv', index=False)
case_5.to_csv('datasets/case_5.csv', index=False)

# %%
inlet_cols = list(inlets.columns)
outlet_cols = list(outlets.columns)
del inlet_cols[:2] # delete 'inlet_Case_id' and 'outlet_fan_speed'
del outlet_cols[:2] # delete 'outlet_Case_id' and 'outlet_fan_speed'

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Case 1

# %%
train_c1, test_c1, val_c1 = train_test_val_split(case_1)

# %% [markdown]
# ### Fan Speed

# %% [markdown]
# #### Inlets

# %%
fig, ax = plt.subplots(figsize=(12,8))
train_c1['inlet_fan_speed'].plot(label="Train")
val_c1['inlet_fan_speed'].plot(label="Validation")
test_c1['inlet_fan_speed'].plot(label="Test")

plt.title("Case 1 - Inlet Fan Speed")
plt.xlabel("Time")
plt.ylabel("Fan Speed")
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(12,8))
train_c1['outlet_fan_speed'].plot(label="Train")
val_c1['outlet_fan_speed'].plot(label="Validation")
test_c1['outlet_fan_speed'].plot(label="Test")

plt.title("Case 1 - Outlet Fan Speed")
plt.xlabel("Time")
plt.ylabel("Fan Speed")
plt.legend()

# %% [markdown]
# ### Temperature

# %% [markdown]
# #### Inlets

# %%
fig, ax = plt.subplots(figsize=(12,8))

# case_1[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", figsize=(12,8), xlabel="Time", ylabel="Average Temperature", label="Average Temperature")
train_c1[inlet_cols].mean(axis=1).plot(label="Train Dataset Average Temperature")
val_c1[inlet_cols].mean(axis=1).plot(label="Validation Dataset Average Temperature")
test_c1[inlet_cols].mean(axis=1).plot(label="Test Dataset Average Temperature")

mean = case_1[inlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# plt.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.title("Average Inlet Temperature (1-135)")
plt.xlabel("Time (5s)")
plt.ylabel("Average Temperature (C°)")

plt.legend()

# %% [markdown]
# #### Outlets

# %%
fig, ax = plt.subplots(figsize=(12,8))

# case_1[outlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", figsize=(12,8), xlabel="Time", ylabel="Average Temperature", label="Average Temperature")
train_c1[outlet_cols].mean(axis=1).plot(label="Train Dataset Average Temperature")
val_c1[outlet_cols].mean(axis=1).plot(label="Validation Dataset Average Temperature")
test_c1[outlet_cols].mean(axis=1).plot(label="Test Dataset Average Temperature")

mean = case_1[outlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# ax.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.title("Average Outlet Temperature (1-135)")
plt.xlabel("Time")
plt.ylabel("Average Temperature (C°)")
plt.legend()

# %% [markdown]
# ## Case 2

# %%
train_c2, test_c2, val_c2 = train_test_val_split(case_2)

# %% [markdown]
# ### Fan Speed

# %% [markdown]
# #### Inlets

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c2["inlet_fan_speed"].plot(label="Train")
val_c2["inlet_fan_speed"].plot(label="Validation")
test_c2["inlet_fan_speed"].plot(label="Test")

plt.title("Case 2 - Inlet Fan Speed")
plt.xlabel("Time (s)")
plt.ylabel("Fan Speed")
plt.legend()

# %% [markdown]
# #### Outlets

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c2["outlet_fan_speed"].plot(label="Train")
val_c2["outlet_fan_speed"].plot(label="Validation")
test_c2["outlet_fan_speed"].plot(label="Test")

plt.title("Case 2 - Outlet Fan Speed")
plt.xlabel("Time (s)")
plt.ylabel("Fan Speed")
plt.legend()

# %% [markdown]
# ### Temperature

# %% [markdown]
# #### Inlets

# %%
fig, ax = plt.subplots(figsize=(12,8))

# case_1[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", figsize=(12,8), xlabel="Time", ylabel="Average Temperature", label="Average Temperature")
train_c2[inlet_cols].mean(axis=1).plot(label="Train Dataset Average Temperature")
val_c2[inlet_cols].mean(axis=1).plot(label="Validation Dataset Average Temperature")
test_c2[inlet_cols].mean(axis=1).plot(label="Test Dataset Average Temperature")

mean = case_2[inlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# ax.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.title("Average Inlet Temperature (1-135)")
plt.xlabel("Time")
plt.ylabel("Average Temperature") 
plt.legend()

# %% [markdown]
# #### Outlets

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c2[outlet_cols].mean(axis=1).plot(label="Train Dataset Average Temperature")
val_c2[outlet_cols].mean(axis=1).plot(label="Validation Dataset Average Temperature")
test_c2[outlet_cols].mean(axis=1).plot(label="Test Dataset Average Temperature")

mean = case_2[outlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# ax.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.title("Average Outlet Temperature (1-135)")
plt.xlabel("Time")
plt.ylabel("Average Temperature") 

plt.legend()

# %% [markdown]
# ## Case 3

# %%
train_c3, test_c3, val_c3 = train_test_val_split(case_3)

# %% [markdown]
# ### Inlet Fan Speed

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c3["inlet_fan_speed"].plot(label="Train")
val_c3["inlet_fan_speed"].plot(label="Validation")
test_c3["inlet_fan_speed"].plot(label="Test")

plt.title("Case 3 - Inlet Fan Speed")
plt.xlabel("Time (s)")
plt.ylabel("Fan Speed")
plt.legend()

# %% [markdown]
# ### Outlet Fan Speed

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c3["outlet_fan_speed"].plot(label="Train")
val_c3["outlet_fan_speed"].plot(label="Validation")
test_c3["outlet_fan_speed"].plot(label="Test")

plt.title("Case 3 - Outlet Fan Speed")
plt.xlabel("Time (s)")
plt.ylabel("Fan Speed")
plt.legend()

# %% [markdown]
# ### Inlet Temperatures

# %%
fig, ax = plt.subplots(figsize=(12,8))

# case_1[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", figsize=(12,8), xlabel="Time", ylabel="Average Temperature", label="Average Temperature")
train_c3[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Train Dataset Average Temperature")
val_c3[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Validation Dataset Average Temperature")
test_c3[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Test Dataset Average Temperature")

mean = case_3[inlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# ax.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.legend()

# %% [markdown]
# ### Outlet Temperatures

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c3[outlet_cols].mean(axis=1).plot(title="Average Outlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Train Dataset Average Temperature")
val_c3[outlet_cols].mean(axis=1).plot(title="Average Outlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Validation Dataset Average Temperature")
test_c3[outlet_cols].mean(axis=1).plot(title="Average Outlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Test Dataset Average Temperature")

mean = case_3[outlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# ax.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.legend()

# %% [markdown]
# ## Case 4

# %%
train_c4, test_c4, val_c4 = train_test_val_split(case_4)

# %% [markdown]
# ### Inlet Fan Speed

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c4["inlet_fan_speed"].plot(label="Train")
val_c4["inlet_fan_speed"].plot(label="Validation")
test_c4["inlet_fan_speed"].plot(label="Test")

plt.title("Case 4 - Inlet Fan Speed")
plt.xlabel("Time (s)")
plt.ylabel("Fan Speed")
plt.legend()

# %% [markdown]
# ### Outlet Fan Speed

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c4["outlet_fan_speed"].plot(label="Train")
val_c4["outlet_fan_speed"].plot(label="Validation")
test_c4["outlet_fan_speed"].plot(label="Test")

plt.title("Case 4 - Outlet Fan Speed")
plt.xlabel("Time (s)")
plt.ylabel("Fan Speed")
plt.legend()

# %% [markdown]
# ### Inlet Temperatures

# %%
fig, ax = plt.subplots(figsize=(12,8))

# case_1[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", figsize=(12,8), xlabel="Time", ylabel="Average Temperature", label="Average Temperature")
train_c4[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Train Dataset Average Temperature")
val_c4[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Validation Dataset Average Temperature")
test_c4[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Test Dataset Average Temperature")

mean = case_4[inlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# ax.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.legend()

# %% [markdown]
# ### Outlet Temperatures

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c4[outlet_cols].mean(axis=1).plot(title="Average Outlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Train Dataset Average Temperature")
val_c4[outlet_cols].mean(axis=1).plot(title="Average Outlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Validation Dataset Average Temperature")
test_c4[outlet_cols].mean(axis=1).plot(title="Average Outlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Test Dataset Average Temperature")

mean = case_4[outlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# ax.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.legend()

# %% [markdown]
# ## Case 5

# %%
train_c5, test_c5, val_c5 = train_test_val_split(case_5)

# %% [markdown]
# ### Inlet Fan Speed

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c5["inlet_fan_speed"].plot(label="Train")
val_c5["inlet_fan_speed"].plot(label="Validation")
test_c5["inlet_fan_speed"].plot(label="Test")

plt.title("Case 5 - Inlet Fan Speed")
plt.xlabel("Time (s)")
plt.ylabel("Fan Speed")
plt.legend()

# %% [markdown]
# ### Outlet Fan Speed

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c5["outlet_fan_speed"].plot(label="Train")
val_c5["outlet_fan_speed"].plot(label="Validation")
test_c5["outlet_fan_speed"].plot(label="Test")

plt.title("Case 5 - Outlet Fan Speed")
plt.xlabel("Time (s)")
plt.ylabel("Fan Speed")
plt.legend()

# %% [markdown]
# ### Inlet Temperature

# %%
fig, ax = plt.subplots(figsize=(12,8))

# case_1[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", figsize=(12,8), xlabel="Time", ylabel="Average Temperature", label="Average Temperature")
train_c5[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Train Dataset Average Temperature")
val_c5[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Validation Dataset Average Temperature")
test_c5[inlet_cols].mean(axis=1).plot(title="Average Inlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Test Dataset Average Temperature")

mean = case_5[inlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# ax.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.legend()

# %% [markdown]
# ### Outlet Temperature

# %%
fig, ax = plt.subplots(figsize=(12,8))

train_c5[outlet_cols].mean(axis=1).plot(title="Average Outlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Train Dataset Average Temperature")
val_c5[outlet_cols].mean(axis=1).plot(title="Average Outlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Validation Dataset Average Temperature")
test_c5[outlet_cols].mean(axis=1).plot(title="Average Outlet Temperature (1-135)", xlabel="Time", ylabel="Average Temperature", label="Test Dataset Average Temperature")

mean = case_5[outlet_cols].mean().mean()
plt.axhline(mean, color='r', linestyle='dashed', label='Mean')
# ax.text(0, mean+0.05, "{:.2f}".format(mean), color='r')

plt.legend()
